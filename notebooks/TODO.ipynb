# %% [markdown]
# # Roadmap
#
# Matthew Bain
# 2024-12-06
#
# 1.  initialize git repo
# 2.  downsample counties
#
# ------------------------------------------------------------------------
#
# 1.  install docker, ngrok
# 2.  dockerize
# 3.  integrate dockerfile with quarto notebook / run locally with ngrok
# 4.  host on snowflake
#
# ## setup
#
# 1.  ~~create environment on T7 (change ‘.env’ `PYTHONPATH`)~~
# 2.  ~~install streamlit~~
# 3.  ~~check rendering of site~~
#
# ## app.py
#
# 1.  ~~load zip code data into python (as geojson?)~~
# 2.  ~~create plotly heatmap of polygons~~
# 3.  ~~host on streamlit~~
#
# ## refinements
#
# ~~part 0~~
#
# 1.  ~~function to load data from link~~
# 2.  ~~clone app & extract jsons~~
#
# ~~part 1~~
#
# 1.  ~~func to save all modules matching pattern from git repo, add
#     outdir arg~~
# 2.  ~~save clickthat geojsons~~ save and extract geojson zips
# 3.  ~~save state names: acronyms as txt file~~
#
# ~~part 3~~
#
# 1.  ~~extract state names in get_state_lookup() to lookup dict~~
# 2.  ~~func to extract {ste_name: {coty_name: \[zcta5_code\]}} lookup
#     dict~~
# 3.  ~~func to plot all zcta5_code’s on map for a given (ste_name,
#     coty_name)~~
# 4.  ~~sign up for mapbox and get free tier token, use mapbox and edit
#     layer~~
# 5.  ~~use zip index for color and include in tooltip~~
# 6.  ~~check zips, use custom palettes, clean up~~
# 7.  ~~parse: st jsons + plt w coty_name as id (poly for st w geo
#     union/diss)~~
# 8.  ~~?add primary dropdown for State and filter second for cty with
#     above~~
#
# -   [zip-codes](https://public.opendatasoft.com/explore/dataset/georef-united-states-of-america-zcta5/export/)
#
# -   [load-medium](https://andrei-misiukevich.medium.com/zip-code-geojson-polygons-for-mapview-c-parser-5c98e8ede07c)
#
# -   [plotly-zipcode](https://medium.com/@mm.fuenteslopez/using-plotly-express-to-make-zip-code-level-choropleth-maps-a8ac8212b7ed)
#
# -   [streamlit-host](https://archive.is/jCJcv#selection-355.0-360.0)
#
# -   [load-mapbox](https://docs.mapbox.com/mapbox-gl-js/example/external-geojson/)
#
# -   [plotly-polygons](https://mapped.newman.me/example-plotly-density-heatmap.html)
#
# -   [gpt](https://chatgpt.com/share/674e433f-24a0-8009-9c35-33aee3db232e)
